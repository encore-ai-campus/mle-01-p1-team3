# %%
import pandas as pd

# %%
df_dict = pd.read_csv("../data/processed/doamain_dictionary/domain_dictionary_v1.csv")
display(df_dict.shape)
display(df_dict.head(10))
# Out:
# (69, 6)
#     term_id canonical_term            aliases category source version
# 0  TERM_001             잠재  잠재 무기|레전 잠재|무기 잠재      아이템  inven      v1
# 1  TERM_002            미트라                NaN      아이템  inven      v1
# 2  TERM_003           제네무기              제네 무기      아이템  inven      v1
# 3  TERM_004             보조                NaN      아이템  inven      v1
# 4  TERM_005             에디                NaN      아이템  inven      v1
# 5  TERM_006             큐브                NaN      아이템  inven      v1
# 6  TERM_007             윗잠                NaN      아이템  inven      v1
# 7  TERM_008            템세팅                NaN      아이템  inven      v1
# 8  TERM_009             레전                NaN      아이템  inven      v1
# 9  TERM_010             코인                NaN      아이템  inven      v1
